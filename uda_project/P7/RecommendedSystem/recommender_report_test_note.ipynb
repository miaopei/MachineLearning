# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from collections import Counter
import tensorflow as tf

import os
import pickle
import re
from tensorflow.python.ops import math_ops

# %%
users_title = ['UserID', 'Gender', 'Age', 'JobID', 'Zip-code']
users = pd.read_table('./ml-1m/users.dat', sep='::', header=None, names=users_title, engine = 'python')
users = users.filter(regex='UserID|Gender|Age|JobID')
users_orig = users.values
#改变User数据中性别和年龄
gender_map = {'F':0, 'M':1}
users['Gender'] = users['Gender'].map(gender_map)

age_map = {item:index for index,item in enumerate([1,18,25,35,45,50,56])}
users['Age'] = users['Age'].map(age_map)

# %%
#读取Movie数据集
movies_title = ['MovieID', 'Title', 'Genres']
movies = pd.read_table('./ml-1m/movies.dat', sep='::', header=None, names=movies_title, engine = 'python')
movies_orig = movies.values

# %%
movies.head()
# Out:
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
#将Title中的年份去掉
pattern = re.compile(r'^(.*)\((\d+)\)$')
title_map = {item:pattern.match(item).group(1) for index,item in enumerate(set(movies['Title']))}
movies['Title'] = movies['Title'].map(title_map)

# %%
movies.head()
# Out:
#    MovieID                         Title                        Genres
# 0        1                    Toy Story    Animation|Children's|Comedy
# 1        2                      Jumanji   Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men                 Comedy|Romance
# 3        4            Waiting to Exhale                   Comedy|Drama
# 4        5  Father of the Bride Part II                         Comedy

# %%
max_title_map = {item:len(item.split()) for index,item in enumerate(set(movies['Title']))}

max(max_title_map.items(), key=lambda x: x[1])
# Out:
# ('Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) ',
#  15)

# %%
title_map
# Out:
# {'Medicine Man ': 2,
#  'Diabolique ': 1,
#  'Intimate Relations ': 2,
#  'Red Sonja ': 2,
#  'Hunted, The ': 2,
#  'Golden Earrings ': 2,
#  'Flubber ': 1,
#  'Working Girl ': 2,
#  'Falcon and the Snowman, The ': 5,
#  'Loves of Carmen, The ': 4,
#  'Raise the Red Lantern ': 4,
#  'Grease 2 ': 2,
#  'Paralyzing Fear: The Story of Polio in America, A ': 9,
#  'Christine ': 1,
#  'Anchors Aweigh ': 2,
#  'Teenage Mutant Ninja Turtles III ': 5,
#  'Up Close and Personal ': 4,
#  'Willow ': 1,
#  'Killer (Bulletproof Heart) ': 3,
#  'Grumpier Old Men ': 3,
#  'Year My Voice Broke, The ': 5,
#  'Boys, The ': 2,
#  'U Turn ': 2,
#  'Giant Gila Monster, The ': 4,
#  'In the Name of the Father ': 6,
#  "Some Mother's Son ": 3,
#  'Fire Within, The (Le Feu Follet) ': 6,
#  'Scent of a Woman ': 4,
#  'E.T. the Extra-Terrestrial ': 3,
#  'Theodore Rex ': 2,
#  'Requiem for a Dream ': 4,
#  'Death and the Maiden ': 4,
#  'Lord of Illusions ': 3,
#  'Dave ': 1,
#  'When Night Is Falling ': 4,
#  'Big Trees, The ': 3,
#  'C�r�monie, La ': 2,
#  'Killing of Sister George, The ': 5,
#  'Perfect World, A ': 3,
#  'Your Friends and Neighbors ': 4,
#  'Heavenly Creatures ': 2,
#  'Manhattan ': 1,
#  'Afterglow ': 1,
#  'Terminator, The ': 2,
#  'Live Flesh ': 2,
#  'Air Up There, The ': 4,
#  'Firewalker ': 1,
#  'Ape, The ': 2,
#  'Faculty, The ': 2,
#  'Apostle, The ': 2,
#  'Circle of Friends ': 3,
#  'Saboteur ': 1,
#  'GoldenEye ': 1,
#  'Zachariah ': 1,
#  'Myth of Fingerprints, The ': 4,
#  'Blade Runner ': 2,
#  'Inside ': 1,
#  'Best of the Best 3: No Turning Back ': 8,
#  'Chuck & Buck ': 3,
#  'Bamboozled ': 1,
#  'Marie Baie Des Anges ': 4,
#  'Hamlet ': 1,
#  'Shadow, The ': 2,
#  'Othello ': 1,
#  'Kika ': 1,
#  'Mighty Morphin Power Rangers: The Movie ': 6,
#  'Weird Science ': 2,
#  'Dinner Game, The (Le D�ner de cons) ': 7,
#  "Child's Play 2 ": 3,
#  'Christmas Story, A ': 3,
#  'Get Carter ': 2,
#  'Barry Lyndon ': 2,
#  'It Takes Two ': 3,
#  'Ballad of Narayama, The (Narayama Bushiko) ': 6,
#  'Alvarez Kelly ': 2,
#  'Circus ': 1,
#  'Looking for Richard ': 3,
#  '8 1/2 Women ': 3,
#  'Fatal Attraction ': 2,
#  'Ponette ': 1,
#  'Meet John Doe ': 3,
#  'Bambi ': 1,
#  'Young Doctors in Love ': 4,
#  "Singin' in the Rain ": 4,
#  'Woman in Question, The ': 4,
#  'New Jersey Drive ': 3,
#  'Opportunists, The ': 2,
#  'Agnes of God ': 3,
#  'Wedding Singer, The ': 3,
#  'Mr. Death: The Rise and Fall of Fred A. Leuchter Jr. ': 11,
#  'Salut cousin! ': 2,
#  '101 Dalmatians ': 2,
#  'Taffin ': 1,
#  'Algiers ': 1,
#  'Fluke ': 1,
#  'Matrix, The ': 2,
#  'Parasite ': 1,
#  'I Love Trouble ': 3,
#  'Lodger, The ': 2,
#  "Porky's II: The Next Day ": 5,
#  'Hunger, The ': 2,
#  "Enfer, L' ": 2,
#  'Senseless ': 1,
#  'Resurrection Man ': 2,
#  'Cutthroat Island ': 2,
#  'Story of Us, The ': 4,
#  'Election ': 1,
#  'Kids of Survival ': 3,
#  'Operation Condor (Feiying gaiwak) ': 4,
#  'Regret to Inform ': 3,
#  'Hands on a Hard Body ': 5,
#  'Blackmail ': 1,
#  'Celluloid Closet, The ': 3,
#  'Titanic ': 1,
#  'Next Friday ': 2,
#  'Sound of Music, The ': 4,
#  'Century ': 1,
#  'Bhaji on the Beach ': 4,
#  'Bastard Out of Carolina ': 4,
#  "Mummy's Hand, The ": 3,
#  'For Your Eyes Only ': 4,
#  'Vermont Is For Lovers ': 4,
#  'Bean ': 1,
#  'Man of No Importance, A ': 5,
#  'Asphalt Jungle, The ': 3,
#  'My Life in Pink (Ma vie en rose) ': 8,
#  'Invisible Man, The ': 3,
#  'Kiss of Death ': 3,
#  'Mute Witness ': 2,
#  'Clockwatchers ': 1,
#  'Pocahontas ': 1,
#  'Breathless ': 1,
#  'Lassie ': 1,
#  'Broadway Damage ': 2,
#  'Love Bewitched, A (El Amor Brujo) ': 6,
#  'Best Men ': 2,
#  'Down Periscope ': 2,
#  'Twisted ': 1,
#  'Original Gangstas ': 2,
#  "Pee-wee's Big Adventure ": 3,
#  'Here Comes Cookie ': 3,
#  'Good Morning, Vietnam ': 3,
#  'Bad Moon ': 2,
#  'Bitter Moon ': 2,
#  'Shadow Conspiracy ': 2,
#  "Boricua's Bond ": 2,
#  "Wayne's World 2 ": 3,
#  'Licence to Kill ': 3,
#  'Emerald Forest, The ': 3,
#  'Mountain Eagle, The ': 3,
#  'Beautiful People ': 2,
#  'Until the End of the World (Bis ans Ende der Welt) ': 11,
#  'West Side Story ': 3,
#  'Caligula ': 1,
#  'Boy Called Hate, A ': 4,
#  'Fright Night ': 2,
#  'Crimes and Misdemeanors ': 3,
#  'Marnie ': 1,
#  'Adventures of Pinocchio, The ': 4,
#  'Dolores Claiborne ': 2,
#  'Daens ': 1,
#  'Letter From Death Row, A ': 5,
#  'Alarmist, The ': 2,
#  'Patriot Games ': 2,
#  'Artemisia ': 1,
#  'Body Shots ': 2,
#  'Coming Home ': 2,
#  'Joyriders, The ': 2,
#  'Get Real ': 2,
#  'Near Dark ': 2,
#  'Charade ': 1,
#  'Affliction ': 1,
#  'Rainmaker, The ': 2,
#  'Portraits Chinois ': 2,
#  'Persuasion ': 1,
#  'Foreign Student ': 2,
#  'Clay Pigeons ': 2,
#  'Turbo: A Power Rangers Movie ': 5,
#  'League of Their Own, A ': 5,
#  'I Still Know What You Did Last Summer ': 8,
#  "Class of Nuke 'Em High ": 5,
#  'Sense and Sensibility ': 3,
#  'Roman Holiday ': 2,
#  'Dangerous Liaisons ': 2,
#  'Scream of Stone (Schrei aus Stein) ': 6,
#  'Simpatico ': 1,
#  'Night Flier ': 2,
#  'Pollyanna ': 1,
#  'Speed 2: Cruise Control ': 4,
#  'Program, The ': 2,
#  'Perfect Blue ': 2,
#  'Gay Divorcee, The ': 3,
#  'Second Best ': 2,
#  'Happy Go Lovely ': 3,
#  'Roadside Prophets ': 2,
#  'Criminal Lovers (Les Amants Criminels) ': 5,
#  'Julien Donkey-Boy ': 2,
#  'Dances with Wolves ': 3,
#  'Jails, Hospitals & Hip-Hop ': 4,
#  'Brady Bunch Movie, The ': 4,
#  'Flesh and Bone ': 3,
#  'Shine ': 1,
#  'Black Sheep ': 2,
#  'Duoluo tianshi ': 2,
#  'Night to Remember, A ': 4,
#  'Scorta, La ': 2,
#  'Fly, The ': 2,
#  'Remember the Titans ': 3,
#  'Graveyard Shift ': 2,
#  'Hard Rain ': 2,
#  'Condition Red ': 2,
#  'Magnolia ': 1,
#  'Teenage Mutant Ninja Turtles ': 4,
#  'Saving Grace ': 2,
#  'Deer Hunter, The ': 3,
#  "Monty Python's Life of Brian ": 5,
#  'Amityville: A New Generation ': 4,
#  'Sixth Sense, The ': 3,
#  'Piano, The ': 2,
#  'Time Masters (Les Ma�tres du Temps) ': 6,
#  'Low Down Dirty Shame, A ': 5,
#  'Getaway, The ': 2,
#  '20 Dates ': 2,
#  'Jerk, The ': 2,
#  'Vibes ': 1,
#  'In the Realm of the Senses (Ai no corrida) ': 9,
#  'Gandhi ': 1,
#  'Echte Kerle ': 2,
#  'Apple Dumpling Gang Rides Again, The ': 6,
#  'Psycho II ': 2,
#  'Bride of Frankenstein ': 3,
#  'Reds ': 1,
#  "Someone Else's America ": 3,
#  'Hercules ': 1,
#  'Chambermaid on the Titanic, The ': 5,
#  'Mighty Joe Young ': 3,
#  "Soldier's Story, A ": 3,
#  'Trans ': 1,
#  'Here on Earth ': 3,
#  'B*A*P*S ': 1,
#  'Great Ziegfeld, The ': 3,
#  'Last Days of Disco, The ': 5,
#  'Three Wishes ': 2,
#  'Anna Karenina ': 2,
#  'It Happened One Night ': 4,
#  'Love Jones ': 2,
#  'Shane ': 1,
#  "Brain That Wouldn't Die, The ": 5,
#  'Thirty-Two Short Films About Glenn Gould ': 6,
#  'Barefoot Executive, The ': 3,
#  'Chopping Mall (a.k.a. Killbots) ': 4,
#  "It's in the Water ": 4,
#  'Flintstones, The ': 2,
#  'MatchMaker, The ': 2,
#  'Jungle Book, The ': 3,
#  'Boxing Helena ': 2,
#  'Withnail and I ': 3,
#  'Fox and the Hound, The ': 5,
#  'Hurricane, The ': 2,
#  'To Wong Foo, Thanks for Everything! Julie Newmar ': 8,
#  'Pelican Brief, The ': 3,
#  'Tomb of Ligeia, The ': 4,
#  'Somewhere in Time ': 3,
#  'Bad Girls ': 2,
#  'Akira ': 1,
#  'Indecent Proposal ': 2,
#  'Crocodile Dundee ': 2,
#  'Under Suspicion ': 2,
#  'Ravenous ': 1,
#  'MURDER and murder ': 3,
#  'Full Speed ': 2,
#  'Gilda ': 1,
#  "Draughtsman's Contract, The ": 3,
#  'Kama Sutra: A Tale of Love ': 6,
#  'Better Living ': 2,
#  'Against All Odds ': 3,
#  'White Boys ': 2,
#  'Winnie the Pooh and the Blustery Day ': 7,
#  'Striptease ': 1,
#  'Great Dictator, The ': 3,
#  'Young Sherlock Holmes ': 3,
#  'Modulations ': 1,
#  'Soul Man ': 2,
#  'Drowning Mona ': 2,
#  "Jupiter's Wife ": 2,
#  'Taste of Cherry ': 3,
#  'Lady and the Tramp ': 4,
#  'Pitch Black ': 2,
#  'Jeffrey ': 1,
#  'In Love and War ': 4,
#  'Double Happiness ': 2,
#  'Psycho ': 1,
#  'House Party 3 ': 3,
#  'Crows and Sparrows ': 3,
#  'Amos & Andrew ': 3,
#  'Fear and Loathing in Las Vegas ': 6,
#  'Tall Tale ': 2,
#  'Crocodile Dundee II ': 3,
#  'Downhill ': 1,
#  'Scream 2 ': 2,
#  'Bringing Out the Dead ': 4,
#  'Restoration ': 1,
#  'Tender Mercies ': 2,
#  'Last Time I Committed Suicide, The ': 6,
#  'Crimes of the Heart ': 4,
#  'Follow the Bitch ': 3,
#  'Roula ': 1,
#  'Re-Animator ': 1,
#  'Peanuts - Die Bank zahlt alles ': 6,
#  'See the Sea (Regarde la mer) ': 6,
#  "You've Got Mail ": 3,
#  'Hour of the Pig, The ': 5,
#  'Getting Even with Dad ': 4,
#  'Being Human ': 2,
#  'From Here to Eternity ': 4,
#  'X-Men ': 1,
#  'Fausto ': 1,
#  'Sweet Nothing ': 2,
#  'Hot Shots! Part Deux ': 4,
#  'Amityville 3-D ': 2,
#  'Natural, The ': 2,
#  'Alice and Martin (Alice et Martin) ': 6,
#  'Toxic Avenger, The ': 3,
#  'My Life as a Dog (Mitt liv som hund) ': 9,
#  'Mighty Peking Man (Hsing hsing wang) ': 6,
#  'Never Met Picasso ': 3,
#  'It Happened Here ': 3,
#  'Amityville Curse, The ': 3,
#  'Voyage to the Bottom of the Sea ': 7,
#  'Mifune (Mifunes sidste sang) ': 4,
#  'Sadness of Sex, The ': 4,
#  'I Stand Alone (Seul contre tous) ': 6,
#  'Gossip ': 1,
#  'Pet Sematary II ': 3,
#  'Universal Soldier ': 2,
#  'Three to Tango ': 3,
#  'Fisher King, The ': 3,
#  'Blood, Guts, Bullets and Octane ': 5,
#  'Education of Little Tree, The ': 5,
#  'Wrongfully Accused ': 2,
#  'Spirits of the Dead (Tre Passi nel Delirio) ': 8,
#  'Way of the Gun, The ': 5,
#  'Richard III ': 2,
#  'Tickle in the Heart, A ': 5,
#  'Species ': 1,
#  'Wild Things ': 2,
#  'Money Train ': 2,
#  'Hedd Wyn ': 2,
#  'Iron Eagle ': 2,
#  'Body Heat ': 2,
#  'It Came from Hollywood ': 4,
#  'Whatever It Takes ': 3,
#  'Melvin and Howard ': 3,
#  'Stay Tuned ': 2,
#  'Tarzan ': 1,
#  'Greatest Show on Earth, The ': 5,
#  'Panther ': 1,
#  'Law, The (Le Legge) ': 4,
#  'Roustabout ': 1,
#  'Thunderbolt and Lightfoot ': 3,
#  'Cure, The ': 2,
#  'Secret Garden, The ': 3,
#  'Pale Rider ': 2,
#  'Strawberry and Chocolate (Fresa y chocolate) ': 6,
#  'Omega Code, The ': 3,
#  'Last Days, The ': 3,
#  'Damien: Omen II ': 3,
#  'Spiders, The (Die Spinnen, 1. Teil: Der Goldene See) ': 9,
#  'Almost Heroes ': 2,
#  'Belle de jour ': 3,
#  'Three Lives and Only One Death ': 6,
#  'Brother Minister: The Assassination of Malcolm X ': 7,
#  'Very Brady Sequel, A ': 4,
#  'Starship Troopers ': 2,
#  'Palm Beach Story, The ': 4,
#  'Ripe ': 1,
#  'Talking About Sex ': 3,
#  'Baby, The ': 2,
#  'What Lies Beneath ': 3,
#  'Ace Ventura: Pet Detective ': 4,
#  'Under Siege ': 2,
#  'Venice/Venice ': 1,
#  'Women, The ': 2,
#  'Net, The ': 2,
#  'Being John Malkovich ': 3,
#  'Friday the 13th Part V: A New Beginning ': 8,
#  'Spanish Fly ': 2,
#  'Snow Falling on Cedars ': 4,
#  'Beans of Egypt, Maine, The ': 5,
#  'Soylent Green ': 2,
#  'Armed and Dangerous ': 3,
#  'Golden Bowl, The ': 3,
#  'Brazil ': 1,
#  'Nina Takes a Lover ': 4,
#  'Fitzcarraldo ': 1,
#  'Runaway ': 1,
#  'Die Hard ': 2,
#  'Pleasantville ': 1,
#  'Endless Summer, The ': 3,
#  'Grosse Fatigue ': 2,
#  'Waiting to Exhale ': 3,
#  'Groove ': 1,
#  'Thunderball ': 1,
#  'Catwalk ': 1,
#  'Raise the Titanic ': 3,
#  "Doug's 1st Movie ": 3,
#  'Mr. & Mrs. Smith ': 4,
#  'Alligator ': 1,
#  'Open Your Eyes (Abre los ojos) ': 6,
#  'Three Kings ': 2,
#  'Judgment Night ': 2,
#  'Live Nude Girls ': 3,
#  'It Conquered the World ': 4,
#  'Taming of the Shrew, The ': 5,
#  'Limelight ': 1,
#  'Bride of Chucky ': 3,
#  'Brothers McMullen, The ': 3,
#  'Radioland Murders ': 2,
#  'Allan Quartermain and the Lost City of Gold ': 8,
#  'Steel Magnolias ': 2,
#  'Indochine ': 1,
#  'Beyond Rangoon ': 2,
#  'Aliens ': 1,
#  'Ed Wood ': 2,
#  'Little Indian, Big City (Un indien dans la ville) ': 9,
#  'Broken Arrow ': 2,
#  "Soldier's Daughter Never Cries, A ": 5,
#  'Trial, The (Le Proc�s) ': 4,
#  'Mrs. Winterbourne ': 2,
#  'Out-of-Towners, The ': 2,
#  'Trixie ': 1,
#  'Escape from New York ': 4,
#  'Get Shorty ': 2,
#  'Dracula: Dead and Loving It ': 5,
#  'Phantom, The ': 2,
#  "Peter's Friends ": 2,
#  'Gun Shy ': 2,
#  'Critical Care ': 2,
#  'And the Band Played On ': 5,
#  'Candidate, The ': 2,
#  'Goofy Movie, A ': 3,
#  'Ninotchka ': 1,
#  'Photographer (Fotoamator) ': 2,
#  'Shower (Xizhao) ': 2,
#  'Tinseltown ': 1,
#  'Casablanca ': 1,
#  'Cool Hand Luke ': 3,
#  'Closer You Get, The ': 4,
#  '1-900 ': 1,
#  'Born to Win ': 3,
#  'NeverEnding Story, The ': 3,
#  'Carriers Are Waiting, The (Les Convoyeurs Attendent) ': 7,
#  'When We Were Kings ': 4,
#  'Nosferatu a Venezia ': 3,
#  'Metropolitan ': 1,
#  'Stealing Home ': 2,
#  'Rude ': 1,
#  'Sleeping Beauty ': 2,
#  'Ready to Rumble ': 3,
#  'Cube ': 1,
#  'Girls Town ': 2,
#  'Perez Family, The ': 3,
#  'Poltergeist III ': 2,
#  'Hackers ': 1,
#  'Hot Spot, The ': 3,
#  'Blue Sky ': 2,
#  'Man for All Seasons, A ': 5,
#  "Nobody's Fool ": 2,
#  'Twin Dragons (Shuang long hui) ': 5,
#  'My Favorite Martian ': 3,
#  'Missing in Action 2: The Beginning ': 6,
#  'Big Country, The ': 3,
#  'Inventing the Abbotts ': 3,
#  'Leave It to Beaver ': 4,
#  'Swamp Thing ': 2,
#  'Train Ride to Hollywood ': 4,
#  'Postman Always Rings Twice, The ': 5,
#  'Robocop 3 ': 2,
#  'Negotiator, The ': 2,
#  'Bad Company ': 2,
#  'Land Before Time III: The Time of the Great Giving ': 10,
#  'Tarzan the Fearless ': 3,
#  'Slaves to the Underground ': 4,
#  'N�nette et Boni ': 3,
#  'Pumpkinhead ': 1,
#  'About Last Night... ': 3,
#  'Endless Summer 2, The ': 4,
#  "House of Exorcism, The (La Casa dell'esorcismo) ": 7,
#  "Boys Don't Cry ": 3,
#  'Notting Hill ': 2,
#  'To Be or Not to Be ': 6,
#  'Madness of King George, The ': 5,
#  '3 Strikes ': 2,
#  'No Way Out ': 3,
#  "Bug's Life, A ": 3,
#  'Immortal Beloved ': 2,
#  'Johnny Mnemonic ': 2,
#  'Out of the Past ': 4,
#  'Scary Movie ': 2,
#  "Clara's Heart ": 2,
#  'Crow: Salvation, The ': 3,
#  'Great Race, The ': 3,
#  'Boys of St. Vincent, The ': 5,
#  'Bottle Rocket ': 2,
#  "You Can't Take It With You ": 6,
#  'Hanging Garden, The ': 3,
#  'Swing Kids ': 2,
#  'Pok�mon the Movie 2000 ': 4,
#  'Rocky Horror Picture Show, The ': 5,
#  'Village of the Damned ': 4,
#  'Soul Food ': 2,
#  'Truman Show, The ': 3,
#  'Star Wars: Episode VI - Return of the Jedi ': 9,
#  'I Married A Strange Person ': 5,
#  'Great Santini, The ': 3,
#  'Married to the Mob ': 4,
#  'Falling in Love Again ': 4,
#  'Hungarian Fairy Tale, A ': 4,
#  'First Blood ': 2,
#  'Ice Storm, The ': 3,
#  'Maurice ': 1,
#  'Men Cry Bullets ': 3,
#  'Go West ': 2,
#  'Creature ': 1,
#  'Sleepy Hollow ': 2,
#  'Howling, The ': 2,
#  'My Blue Heaven ': 3,
#  'Children of Paradise (Les enfants du paradis) ': 7,
#  'Two Moon Juction ': 3,
#  'Mafia! ': 1,
#  'Hellhounds on My Trail ': 4,
#  "Brown's Requiem ": 2,
#  'Queen Margot (La Reine Margot) ': 5,
#  'Escape from the Planet of the Apes ': 7,
#  'Ghosts of Mississippi ': 3,
#  'All Dogs Go to Heaven ': 5,
#  'Thieves (Voleurs, Les) ': 3,
#  'Piranha ': 1,
#  'Goodbye, 20th Century (Zbogum na dvadesetiot vek) ': 7,
#  'Deadly Friend ': 2,
#  'Babyfever ': 1,
#  'Mortal Thoughts ': 2,
#  'Boondock Saints, The ': 3,
#  'Two Crimes ': 2,
#  'Eternity and a Day (Mia eoniotita ke mia mera ) ': 10,
#  'Sliver ': 1,
#  'Romper Stomper ': 2,
#  'Last Temptation of Christ, The ': 5,
#  'Music From Another Room ': 4,
#  'Mirage ': 1,
#  'He Got Game ': 3,
#  'Navigator: A Mediaeval Odyssey, The ': 5,
#  'Cement Garden, The ': 3,
#  'Home Alone ': 2,
#  'Night of the Living Dead ': 5,
#  'In Search of the Castaways ': 5,
#  'Marked for Death ': 3,
#  '$1,000,000 Duck ': 2,
#  'Mating Habits of the Earthbound Human, The ': 7,
#  'Parenthood ': 1,
#  'Spellbound ': 1,
#  'My Fair Lady ': 3,
#  'African Queen, The ': 3,
#  'Dream for an Insomniac ': 4,
#  'Doctor Dolittle ': 2,
#  'Barenaked in America ': 3,
#  'Rudy ': 1,
#  'Pacific Heights ': 2,
#  'Hate (Haine, La) ': 3,
#  'Commitments, The ': 2,
#  'Godzilla 2000 (Gojira ni-sen mireniamu) ': 5,
#  'Sleepover ': 1,
#  'Right Stuff, The ': 3,
#  'Blues Brothers 2000 ': 3,
#  'I.Q. ': 1,
#  'Truce, The ': 2,
#  'Trading Places ': 2,
#  'Madame Butterfly ': 2,
#  'Naked ': 1,
#  'Quest, The ': 2,
#  'Wings of Desire (Der Himmel �ber Berlin) ': 7,
#  'Wife, The ': 2,
#  'Friday the 13th Part 2 ': 5,
#  'Alphaville ': 1,
#  'Tom & Viv ': 3,
#  'Cobb ': 1,
#  'Hellbound: Hellraiser II ': 3,
#  'Mulan ': 1,
#  'Sword in the Stone, The ': 5,
#  'Mille bolle blu ': 3,
#  'Last Dance ': 2,
#  'Jurassic Park ': 2,
#  'Peggy Sue Got Married ': 4,
#  'Quarry, The ': 2,
#  'Eye for an Eye ': 4,
#  'Casino ': 1,
#  'Autumn in New York ': 4,
#  'My Chauffeur ': 2,
#  'Titus ': 1,
#  'Battle of the Sexes, The ': 5,
#  'Savior ': 1,
#  'Dragonheart ': 1,
#  'Nashville ': 1,
#  'Hear My Song ': 3,
#  'Tales From the Crypt Presents: Demon Knight ': 7,
#  'Spaceballs ': 1,
#  'Stepford Wives, The ': 3,
#  'Thing From Another World, The ': 5,
#  'Earth Vs. the Flying Saucers ': 5,
#  'Stigmata ': 1,
#  'Two or Three Things I Know About Her ': 8,
#  'Wirey Spindell ': 2,
#  'Sandpiper, The ': 2,
#  'Secret Agent ': 2,
#  'Century of Cinema, A ': 4,
#  'Cradle Will Rock, The ': 4,
#  'Selena ': 1,
#  'Wings of Courage ': 3,
#  'Godfather: Part II, The ': 4,
#  'Back to the Future Part II ': 6,
#  'Country ': 1,
#  'Und keiner weint mir nach ': 5,
#  'Stop! Or My Mom Will Shoot ': 6,
#  'Belizaire the Cajun ': 3,
#  'Beyond the Poseidon Adventure ': 4,
#  'Under the Domin Tree (Etz Hadomim Tafus) ': 7,
#  'Grapes of Wrath, The ': 4,
#  'River, The ': 2,
#  'Easy Money ': 2,
#  'Buddy Boy ': 2,
#  'Unforgiven ': 1,
#  'Guinevere ': 1,
#  "Dante's Peak ": 2,
#  'Good Will Hunting ': 3,
#  'Wonderland ': 1,
#  'Malcolm X ': 2,
#  'Three Days of the Condor ': 5,
#  'Four Rooms ': 2,
#  'Another Stakeout ': 2,
#  'Unforgotten: Twenty-Five Years After Willowbrook ': 5,
#  'Cotton Mary ': 2,
#  'Love and Death ': 3,
#  'Home Alone 2: Lost in New York ': 7,
#  'Geronimo: An American Legend ': 4,
#  'Deep Impact ': 2,
#  'Dead Zone, The ': 3,
#  'Stranger Than Paradise ': 3,
#  'To Live (Huozhe) ': 3,
#  'Germinal ': 1,
#  'Bananas ': 1,
#  'Stepmom ': 1,
#  'Whole Nine Yards, The ': 4,
#  'Little City ': 2,
#  'Gothic ': 1,
#  'Robin Hood: Prince of Thieves ': 5,
#  'Drive Me Crazy ': 3,
#  'In Crowd, The ': 3,
#  'Killer Shrews, The ': 3,
#  'Small Wonders ': 2,
#  'Mr. Jealousy ': 2,
#  'Forget Paris ': 2,
#  'Nell ': 1,
#  'Broadcast News ': 2,
#  'Tumbleweeds ': 1,
#  'Jack ': 1,
#  'Napoleon and Samantha ': 3,
#  'Three Colors: Blue ': 3,
#  'Journey of August King, The ': 5,
#  'Six-String Samurai ': 2,
#  'Ghost and the Darkness, The ': 5,
#  'Cutting Edge, The ': 3,
#  'Some Folks Call It a Sling Blade ': 7,
#  'Prophecy II, The ': 3,
#  'Still Breathing ': 2,
#  'Gone in 60 Seconds ': 4,
#  'Party Girl ': 2,
#  "She's the One ": 3,
#  'American in Paris, An ': 4,
#  'Rain Man ': 2,
#  "One Man's Hero ": 3,
#  'Glass Bottom Boat, The ': 4,
#  'Waking the Dead ': 3,
#  'Of Love and Shadows ': 4,
#  'Gospa ': 1,
#  'High Fidelity ': 2,
#  'Chungking Express ': 2,
#  'Naked Gun 33 1/3: The Final Insult ': 7,
#  'Lonely Are the Brave ': 4,
#  'Mission to Mars ': 3,
#  'Things Change ': 2,
#  'Son of Dracula ': 3,
#  'Mad City ': 2,
#  'Jefferson in Paris ': 3,
#  'Top Gun ': 2,
#  'Never Cry Wolf ': 3,
#  'Runaway Train ': 2,
#  'Idiots, The (Idioterne) ': 3,
#  'Waking Ned Devine ': 3,
#  'Castaway Cowboy, The ': 3,
#  'Seven (Se7en) ': 2,
#  'Empty Mirror, The ': 3,
#  'Little Women ': 2,
#  "Mummy's Curse, The ": 3,
#  'Desperate Measures ': 2,
#  'Cable Guy, The ': 3,
#  'Peter Pan ': 2,
#  'Snowriders ': 1,
#  'All Over Me ': 3,
#  'Tarantula ': 1,
#  'Hard-Boiled (Lashou shentan) ': 3,
#  'Somebody is Waiting ': 3,
#  "Let's Get Harry ": 3,
#  'Halloween: H20 ': 2,
#  'Anatomy (Anatomie) ': 2,
#  'Big Bully ': 2,
#  'Sprung ': 1,
#  'Reluctant Debutante, The ': 3,
#  'Dersu Uzala ': 2,
#  'Strangers on a Train ': 4,
#  'Best Years of Our Lives, The ': 6,
#  'Mortal Kombat: Annihilation ': 3,
#  "Smilla's Sense of Snow ": 4,
#  'Tales of Terror ': 3,
#  'Flashdance ': 1,
#  'While You Were Sleeping ': 4,
#  'Excalibur ': 1,
#  'Supercop ': 1,
#  'Broken Hearts Club, The ': 4,
#  'Beautiful Thing ': 2,
#  'I Like It Like That ': 5,
#  'Money Talks ': 2,
#  'Eddie ': 1,
#  'Dog Day Afternoon ': 3,
#  'Texas Chainsaw Massacre, The ': 4,
#  'Reach the Rock ': 3,
#  'Across the Sea of Time ': 5,
#  'Faces ': 1,
#  'Jimmy Hollywood ': 2,
#  "White Man's Burden ": 3,
#  'Force of Evil ': 3,
#  "School of Flesh, The (L' �cole de la chair) ": 9,
#  "It's a Wonderful Life ": 4,
#  'Funny Farm ': 2,
#  'Abyss, The ': 2,
#  'Nikita (La Femme Nikita) ': 4,
#  'Project Moon Base ': 3,
#  'War at Home, The ': 4,
#  'Cold Comfort Farm ': 3,
#  'Carrie ': 1,
#  'Any Given Sunday ': 3,
#  'Anastasia ': 1,
#  'Manxman, The ': 2,
#  'Night on Earth ': 3,
#  'Canadian Bacon ': 2,
#  'In the Company of Men ': 5,
#  'Endurance ': 1,
#  'Exit to Eden ': 3,
#  'Alley Cats, The ': 3,
#  'Shadowlands ': 1,
#  'Robocop ': 1,
#  'West Beirut (West Beyrouth) ': 4,
#  'Prince of Central Park, The ': 5,
#  'Love and a .45 ': 4,
#  'Searching for Bobby Fischer ': 4,
#  'Jackie Brown ': 2,
#  'Gung Ho ': 2,
#  'Gypsy ': 1,
#  'Howling II: Your Sister Is a Werewolf ': 7,
#  'Junior ': 1,
#  'Dream With the Fishes ': 4,
#  'Beach Party ': 2,
#  'Billy Madison ': 2,
#  'Splendor ': 1,
#  'Love! Valour! Compassion! ': 3,
#  'Trees Lounge ': 2,
#  "Barney's Great Adventure ": 3,
#  '20,000 Leagues Under the Sea ': 5,
#  'Strange Days ': 2,
#  'Penitentiary II ': 2,
#  'Man of the Year ': 4,
#  'Terminator 2: Judgment Day ': 4,
#  'Children of the Corn IV: The Gathering ': 7,
#  'Two Friends ': 2,
#  'Costa Brava ': 2,
#  'Unhook the Stars ': 3,
#  'Bob Roberts ': 2,
#  'Pushing Tin ': 2,
#  'American Strays ': 2,
#  'Message in a Bottle ': 4,
#  'Telling You ': 2,
#  'Ulysses (Ulisse) ': 2,
#  'Affair to Remember, An ': 4,
#  'Sling Blade ': 2,
#  'Mad Dog Time ': 3,
#  'Burnt Offerings ': 2,
#  'Iron Eagle IV ': 3,
#  'Close Shave, A ': 3,
#  "Charm's Incidents ": 2,
#  'Wishmaster ': 1,
#  'Puppet Master II ': 3,
#  'Prerokbe Ognja ': 2,
#  'Chinese Box ': 2,
#  'Happiness ': 1,
#  'Wedding Bell Blues ': 3,
#  'Tex ': 1,
#  'Velvet Goldmine ': 2,
#  'Mumford ': 1,
#  'Diner ': 1,
#  'Firm, The ': 2,
#  'How I Won the War ': 5,
#  'Condorman ': 1,
#  'Georgia ': 1,
#  'Outrageous Fortune ': 2,
#  'Safe ': 1,
#  'Love and Other Catastrophes ': 4,
#  'Ipcress File, The ': 3,
#  'Highlander: Endgame ': 2,
#  'Man from Laramie, The ': 4,
#  "What's Love Got to Do with It? ": 7,
#  'Father of the Bride Part II ': 6,
#  'Relic, The ': 2,
#  'Cook the Thief His Wife & Her Lover, The ': 9,
#  'Kiss Me, Guido ': 3,
#  'That Old Feeling ': 3,
#  'Dr. No ': 2,
#  'Under the Rainbow ': 3,
#  "Jesus' Son ": 2,
#  'Muppet Christmas Carol, The ': 4,
#  "Dog's Life, A ": 3,
#  'Me, Myself and Irene ': 4,
#  'Get Over It ': 3,
#  'From the Journals of Jean Seberg ': 6,
#  'When a Man Loves a Woman ': 6,
#  'Flipper ': 1,
#  'Man in the Iron Mask, The ': 6,
#  'Wilde ': 1,
#  'Monkey Shines ': 2,
#  'Player, The ': 2,
#  'Hellraiser ': 1,
#  'Jules and Jim (Jules et Jim) ': 6,
#  'Zero Effect ': 2,
#  'Fistful of Dollars, A ': 4,
#  'Mouth to Mouth (Boca a boca) ': 6,
#  'Jar, The (Khomreh) ': 3,
#  "Mr. Holland's Opus ": 3,
#  'Faust ': 1,
#  'Whole Wide World, The ': 4,
#  'Grand Canyon ': 2,
#  'Little Shop of Horrors ': 4,
#  'Butcher Boy, The ': 3,
#  'Madagascar Skin ': 2,
#  'Somewhere in the City ': 4,
#  'Nekromantik ': 1,
#  'Superman ': 1,
#  'Daughter of Dr. Jeckyll ': 4,
#  'Mary Reilly ': 2,
#  'Lost Son, The ': 3,
#  'Hollow Reed ': 2,
#  'Nightmares ': 1,
#  'Godfather: Part III, The ': 4,
#  'Random Hearts ': 2,
#  'Stalag 17 ': 2,
#  'Beyond the Mat ': 3,
#  'Red Firecracker, Green Firecracker ': 4,
#  'Clerks ': 1,
#  'Bay of Blood (Reazione a catena) ': 6,
#  'Newton Boys, The ': 3,
#  'Passion in the Desert ': 4,
#  'Three Ages, The ': 3,
#  'Pope of Greenwich Village, The ': 5,
#  'Event Horizon ': 2,
#  'Rescuers, The ': 2,
#  "Kid in King Arthur's Court, A ": 6,
#  'Godzilla ': 1,
#  'Haunting, The ': 2,
#  'Robin Hood ': 2,
#  'I Know What You Did Last Summer ': 7,
#  'Ben-Hur ': 1,
#  'Raiders of the Lost Ark ': 5,
#  'Adventures of Sebastian Cole, The ': 5,
#  'Close Encounters of the Third Kind ': 6,
#  'Carnosaur 3: Primal Species ': 4,
#  'Mission: Impossible 2 ': 3,
#  'Boys Life ': 2,
#  'Beloved ': 1,
#  'Decline of Western Civilization Part II: The Metal Years, The ': 10,
#  'Steal This Movie! ': 3,
#  "Porky's ": 1,
#  'Mondo ': 1,
#  'Alien Escape ': 2,
#  'Wonder Boys ': 2,
#  'Flamingo Kid, The ': 3,
#  'Beverly Hills Ninja ': 3,
#  'Police Academy 3: Back in Training ': 6,
#  'Home Page ': 2,
#  'Rosencrantz and Guildenstern Are Dead ': 5,
#  'Drop Dead Fred ': 3,
#  'Bandits ': 1,
#  'Bedrooms & Hallways ': 3,
#  'Seventh Heaven (Le Septi�me ciel) ': 5,
#  'Rocketeer, The ': 2,
#  "But I'm a Cheerleader ": 4,
#  'Nick of Time ': 3,
#  'Eraserhead ': 1,
#  'Celestial Clockwork ': 2,
#  'House of Yes, The ': 4,
#  'Poison Ivy ': 2,
#  'Celebration, The (Festen) ': 3,
#  'Up in Smoke ': 3,
#  'Star Wars: Episode IV - A New Hope ': 8,
#  'Mission: Impossible ': 2,
#  'Incognito ': 1,
#  'Rules of Engagement ': 3,
#  'Last Time I Saw Paris, The ': 6,
#  'Alice in Wonderland ': 3,
#  "Midsummer Night's Dream, A ": 4,
#  'Living Dead Girl, The (La Morte Vivante) ': 7,
#  'Good Earth, The ': 3,
#  'Thin Line Between Love and Hate, A ': 7,
#  'One Crazy Summer ': 3,
#  'Grace of My Heart ': 4,
#  'Marty ': 1,
#  'Stalingrad ': 1,
#  'Bride of Re-Animator ': 3,
#  'Institute Benjamenta, or This Dream People Call Human Life ': 9,
#  'Jeremiah Johnson ': 2,
#  'Herbie Goes to Monte Carlo ': 5,
#  'All Dogs Go to Heaven 2 ': 6,
#  'Terror in a Texas Town ': 5,
#  "Breakfast at Tiffany's ": 3,
#  'Lady Vanishes, The ': 3,
#  'Peacemaker, The ': 2,
#  'Night at the Roxbury, A ': 5,
#  'Communion ': 1,
#  'Boys ': 1,
#  'Death Wish 3 ': 3,
#  "God Said 'Ha!' ": 3,
#  'Love & Sex ': 3,
#  'Howard the Duck ': 3,
#  'Meteor ': 1,
#  'Paulie ': 1,
#  'Instinct ': 1,
#  'Cry, the Beloved Country ': 4,
#  'Aladdin and the King of Thieves ': 6,
#  "McHale's Navy ": 2,
#  'Great Escape, The ': 3,
#  'From Dusk Till Dawn ': 4,
#  'Alive ': 1,
#  'Double Indemnity ': 2,
#  'Touch of Evil ': 3,
#  'Rob Roy ': 2,
#  'Treasure of the Sierra Madre, The ': 6,
#  'Great Expectations ': 2,
#  'Good, The Bad and The Ugly, The ': 7,
#  'Blink ': 1,
#  'New Age, The ': 3,
#  'Ayn Rand: A Sense of Life ': 6,
#  'How Stella Got Her Groove Back ': 6,
#  'Kill, Baby... Kill! (Operazione Paura) ': 5,
#  'Payback ': 1,
#  'Boogie Nights ': 2,
#  'Honey, I Blew Up the Kid ': 6,
#  'My Science Project ': 3,
#  'Simply Irresistible ': 2,
#  'Liebelei ': 1,
#  'End of Violence, The ': 4,
#  'Marlene Dietrich: Shadow and Light ': 5,
#  'Kim ': 1,
#  'Old Man and the Sea, The ': 6,
#  'Sacco and Vanzetti (Sacco e Vanzetti) ': 6,
#  'Perfect Storm, The ': 3,
#  'Two Family House ': 3,
#  'Great Mouse Detective, The ': 4,
#  '13th Warrior, The ': 3,
#  'Truth About Cats & Dogs, The ': 6,
#  'Big ': 1,
#  'Fog, The ': 2,
#  'Blue Lagoon, The ': 3,
#  'My Favorite Season ': 3,
#  'Zeus and Roxanne ': 3,
#  'Down in the Delta ': 4,
#  "Stacy's Knights ": 2,
#  'Life ': 1,
#  'Country Life ': 2,
#  'Mansfield Park ': 2,
#  'Masque of the Red Death, The ': 6,
#  'Outside Ozona ': 2,
#  'Omega Man, The ': 3,
#  "Widows' Peak ": 2,
#  'Sparrows ': 1,
#  'Loss of Sexual Innocence, The ': 5,
#  'Sid and Nancy ': 3,
#  'Professional, The (a.k.a. Leon: The Professional) ': 6,
#  'Full Metal Jacket ': 3,
#  'Johns ': 1,
#  'Crimson Tide ': 2,
#  'Burglar ': 1,
#  'Heaven ': 1,
#  'Before and After ': 3,
#  'Friend of the Deceased, A ': 5,
#  ...}

# %%
#电影类型转数字字典
genres_set = set()
for item in movies['Genres'].str.split('|'):
    genres_set.update(item)

genres_set.add('<PAD>')
genres2int = {item:index for index,item in enumerate(genres_set)}

# %%
genres2int
# Out:
# {'<PAD>': 8,
#  'Action': 2,
#  'Adventure': 1,
#  'Animation': 11,
#  "Children's": 15,
#  'Comedy': 6,
#  'Crime': 12,
#  'Documentary': 10,
#  'Drama': 9,
#  'Fantasy': 0,
#  'Film-Noir': 5,
#  'Horror': 4,
#  'Musical': 14,
#  'Mystery': 7,
#  'Romance': 17,
#  'Sci-Fi': 18,
#  'Thriller': 3,
#  'War': 16,
#  'Western': 13}

# %%
#将电影类型转成等长数字列表，长度是18
genres_map = {item:[genres2int[row] for row in item.split('|')] for index,item in enumerate(set(movies['Genres']))}

for key in genres_map:
    for cnt in range(max(genres2int.values()) - len(genres_map[key])):
        genres_map[key].insert(len(genres_map[key]) + cnt,genres2int['<PAD>'])

movies['Genres'] = movies['Genres'].map(genres_map)

# %%
#电影Title转数字字典
title_set = set()
for val in movies['Title'].str.split():
    title_set.update(val)

title_set.add('<PAD>')
title2int = {val:ii for ii, val in enumerate(title_set)}

# %%
title2int
# Out:
# {'Check': 0,
#  'May': 1,
#  'Crocodile': 2,
#  'Apart': 3,
#  '60': 4,
#  'pastorale,': 5,
#  'Avengers,': 6,
#  'de': 7,
#  'k�ldum': 8,
#  '(Et': 9,
#  'Lian)': 10,
#  'Mating': 11,
#  'Total': 12,
#  'Greenwich': 13,
#  'Cuts': 14,
#  '(Saimt': 15,
#  'Trip': 16,
#  'Valiant': 17,
#  'Cold': 18,
#  'Chungking': 19,
#  'Harriet': 20,
#  'Storm,': 21,
#  'Whatever': 22,
#  'Behavior': 23,
#  'Stop': 24,
#  "Cat's": 25,
#  'Pajama': 26,
#  'Strikes': 27,
#  'Team': 28,
#  'Case,': 29,
#  'Extremities': 30,
#  'Sacrifice': 31,
#  'Shane': 32,
#  "Farmer's": 33,
#  'Morning': 34,
#  'Douce': 35,
#  'Uninvited': 36,
#  'Odyssey,': 37,
#  'Enterprise': 38,
#  '(Rosso': 39,
#  'Dazed': 40,
#  'Roma': 41,
#  "Pete's": 42,
#  'Couple,': 43,
#  'Cider': 44,
#  'Angela': 45,
#  'Dollhouse': 46,
#  'Drugstore': 47,
#  'Committed': 48,
#  'Ross': 49,
#  'Gun,': 50,
#  '3-D': 51,
#  'Making': 52,
#  "McHale's": 53,
#  'Grape': 54,
#  'Two': 55,
#  'Secreto)': 56,
#  'Maybe,': 57,
#  'Tombstone': 58,
#  'Sexual': 59,
#  'Honey,': 60,
#  'Lifeboat': 61,
#  'Steam:': 62,
#  'Soft': 63,
#  'Guess': 64,
#  'Brother,': 65,
#  'China': 66,
#  'Person': 67,
#  'Judge': 68,
#  'Business': 69,
#  'Anywhere': 70,
#  'Urbania': 71,
#  'Jimmy,': 72,
#  'Wonderful,': 73,
#  'Wanted:': 74,
#  'Ferox)': 75,
#  'Mat': 76,
#  'Happy': 77,
#  'Revolution,': 78,
#  'Trek:': 79,
#  'Wives': 80,
#  'Dust': 81,
#  'Heartbreak': 82,
#  "King's": 83,
#  'Monsieur': 84,
#  'Ballou': 85,
#  'Operation': 86,
#  "L')": 87,
#  'Their': 88,
#  "Warhol's": 89,
#  'sidste': 90,
#  'Piano,': 91,
#  'Andy': 92,
#  'Come': 93,
#  'Mowgli': 94,
#  'Sling': 95,
#  'Peking': 96,
#  'Than': 97,
#  'Magnum': 98,
#  'Cutting': 99,
#  'Monster': 100,
#  'Mask': 101,
#  'Xiu': 102,
#  'Lips': 103,
#  'Amy': 104,
#  '(Falkens': 105,
#  'Immortal': 106,
#  'Relations': 107,
#  'Jersey': 108,
#  'Surviving': 109,
#  'Locusts,': 110,
#  "Dinosaur's": 111,
#  'Navy': 112,
#  'Buena': 113,
#  '(Leggenda': 114,
#  'Killing,': 115,
#  'Roseanna)': 116,
#  'Germinal': 117,
#  'Dredd': 118,
#  'Roof,': 119,
#  'Pesos': 120,
#  'Vampires': 121,
#  'al': 122,
#  'Bondage': 123,
#  'Matewan': 124,
#  'Pink': 125,
#  'Lost': 126,
#  'Threesome': 127,
#  'Ninotchka': 128,
#  'Dingo': 129,
#  'Separation': 130,
#  'Illusions': 131,
#  'Row,': 132,
#  'Days': 133,
#  'Weird': 134,
#  'Patriot,': 135,
#  'Messenger:': 136,
#  'Bulworth': 137,
#  'Asphalt': 138,
#  'Septi�me': 139,
#  'Wing': 140,
#  'Harold': 141,
#  'Jakes,': 142,
#  'Denise': 143,
#  'Bullwinkle,': 144,
#  'Kull': 145,
#  'Parent': 146,
#  '1600': 147,
#  '(Callej�n': 148,
#  'Kwai,': 149,
#  'Hunchback': 150,
#  '(Keiner': 151,
#  'Tap': 152,
#  'Dog': 153,
#  'Professional,': 154,
#  'Wishmaster': 155,
#  'Gang': 156,
#  'Finding': 157,
#  "Mo'": 158,
#  'X-M': 159,
#  '(Auch': 160,
#  'Seasons,': 161,
#  'Maps': 162,
#  'Times': 163,
#  'Waltzes': 164,
#  'da': 165,
#  'McCullochs,': 166,
#  'Vincent,': 167,
#  'Kaspar': 168,
#  'Jude': 169,
#  'Dead,': 170,
#  'son': 171,
#  'Murder,': 172,
#  'Breaking': 173,
#  'Alan': 174,
#  'Scout,': 175,
#  'va)': 176,
#  'Panchali': 177,
#  'Around': 178,
#  'sources)': 179,
#  'Crow,': 180,
#  'cioccolata)': 181,
#  'Becomes': 182,
#  'Nobody': 183,
#  'Nighthawks': 184,
#  'Move': 185,
#  'Minnie': 186,
#  'League:': 187,
#  'Shiloh': 188,
#  'Framed': 189,
#  'Radioland': 190,
#  'castrato': 191,
#  'Washington': 192,
#  'We': 193,
#  'Hall': 194,
#  'Chamber,': 195,
#  'Outlaw,': 196,
#  'klein': 197,
#  'Toxie,': 198,
#  'Presents:': 199,
#  '2001:': 200,
#  'Sun,': 201,
#  'Eyre': 202,
#  'Legs': 203,
#  'Territory': 204,
#  'Friends': 205,
#  'Nina': 206,
#  'Himmel': 207,
#  'Sinbad,': 208,
#  'qin': 209,
#  'Sleep,': 210,
#  'Artaud)': 211,
#  'Calendar': 212,
#  "L'": 213,
#  'Cemetery': 214,
#  'Pop.': 215,
#  'Sun': 216,
#  'Apple': 217,
#  'Alice,': 218,
#  'Thirty-Two': 219,
#  'Tuned': 220,
#  'Kelly': 221,
#  'Basquiat': 222,
#  'Afternoon': 223,
#  'North': 224,
#  'Disturbing': 225,
#  'Killbots)': 226,
#  'Guerre,': 227,
#  "Ramblin'": 228,
#  'Claus:': 229,
#  'Neon': 230,
#  'Proxy,': 231,
#  'Game,': 232,
#  'Wolves,': 233,
#  'Alien�': 234,
#  'Perils': 235,
#  'Science': 236,
#  'Meteor': 237,
#  'Thief': 238,
#  'Rings,': 239,
#  'Pest,': 240,
#  'Impact': 241,
#  'Ducks,': 242,
#  'Palm': 243,
#  'Halloween:': 244,
#  'Spinnen,': 245,
#  'Sacco': 246,
#  'Bleu)': 247,
#  'Sleeper': 248,
#  'Mankind': 249,
#  'Spirits,': 250,
#  'Hippie': 251,
#  'Segno': 252,
#  'Callej�n': 253,
#  'Bordeaux': 254,
#  'Needful': 255,
#  'dvadesetiot': 256,
#  'Secrets': 257,
#  'Buckaroo': 258,
#  'Sparks': 259,
#  'Mute': 260,
#  'Plennik)': 261,
#  'Brooklyn': 262,
#  "You've": 263,
#  'Shoot': 264,
#  'Erin': 265,
#  'Until': 266,
#  'Fitzcarraldo': 267,
#  'Journal': 268,
#  'boca)': 269,
#  'B*A*P*S': 270,
#  'Local': 271,
#  'Rebecca': 272,
#  'Powder': 273,
#  "Muriel's": 274,
#  'Outlaws': 275,
#  'Goodbye': 276,
#  'Audrey': 277,
#  'Morning,': 278,
#  'Dorothy': 279,
#  'False': 280,
#  'Gambler,': 281,
#  'Yol': 282,
#  'Barrels': 283,
#  'Topaz': 284,
#  'Glengarry': 285,
#  'Express': 286,
#  'Sharks': 287,
#  '(Soy': 288,
#  'Breathless': 289,
#  'SS': 290,
#  'Herbie': 291,
#  'Heat': 292,
#  'James': 293,
#  'macor)': 294,
#  'Showgirls': 295,
#  'Batch': 296,
#  'et': 297,
#  'Demolition': 298,
#  'Periscope': 299,
#  'Indiana': 300,
#  'Tennis': 301,
#  'Natty': 302,
#  '1975': 303,
#  '(S�ndagsengler)': 304,
#  'October,': 305,
#  'Shanghai': 306,
#  'Sugar': 307,
#  'Talk': 308,
#  'Ivy': 309,
#  'Boys,': 310,
#  'Browne': 311,
#  'Largo': 312,
#  'Network': 313,
#  "Lilian's": 314,
#  'Minded': 315,
#  'Bible,': 316,
#  '(Central': 317,
#  'Program,': 318,
#  'Driving': 319,
#  'Bottom': 320,
#  'Shave,': 321,
#  'Front': 322,
#  'Yojimbo': 323,
#  'Bunch': 324,
#  'Cross': 325,
#  "Brother's": 326,
#  'Goat': 327,
#  'Patton': 328,
#  'Kindred,': 329,
#  'Uzala': 330,
#  'Feast': 331,
#  'Possession': 332,
#  'Africa,': 333,
#  'Plaid': 334,
#  'Children,': 335,
#  'Fletch': 336,
#  'Nueba': 337,
#  'Bound': 338,
#  'People': 339,
#  'Age,': 340,
#  'Sour': 341,
#  'Slam': 342,
#  'Artaud': 343,
#  'Camelot': 344,
#  "Bustin'": 345,
#  'March': 346,
#  'You': 347,
#  'Bed': 348,
#  'Feet': 349,
#  'Re-Animator': 350,
#  'Boy,': 351,
#  'Shoulder': 352,
#  'Josey': 353,
#  'Gift,': 354,
#  'Impossible': 355,
#  'Contender,': 356,
#  'Labyrinth': 357,
#  'Fresh': 358,
#  '.45': 359,
#  'Flintstones': 360,
#  "(God's": 361,
#  'Goldfinger': 362,
#  'Feind)': 363,
#  'Bros.': 364,
#  'Kundun': 365,
#  'Jafar,': 366,
#  'Consequences,': 367,
#  'Majesty,': 368,
#  'Broke,': 369,
#  '(Operazione': 370,
#  'Spot,': 371,
#  'Awfully': 372,
#  'Son,': 373,
#  'Groundhog': 374,
#  'Ognja': 375,
#  'Dudley': 376,
#  'd�but': 377,
#  'Hang': 378,
#  "Cuckoo's": 379,
#  'Ordinary': 380,
#  'Moonlight': 381,
#  'gaiwak)': 382,
#  'tianshi': 383,
#  "Kestrel's": 384,
#  'Solaris': 385,
#  'Rage)': 386,
#  '(De': 387,
#  'Lo': 388,
#  'Full': 389,
#  'Gang,': 390,
#  'Stupids,': 391,
#  'Playing': 392,
#  'Suicides,': 393,
#  'Legends:': 394,
#  'Cole,': 395,
#  'Dear': 396,
#  'Whole': 397,
#  'Yesterday': 398,
#  'Doors,': 399,
#  'Club,': 400,
#  'Condor': 401,
#  'Cheap': 402,
#  'Suspicion': 403,
#  'Scream': 404,
#  'Parallel': 405,
#  'di': 406,
#  'If....': 407,
#  'Girl,': 408,
#  'Ninth': 409,
#  '(Schrei': 410,
#  'Die': 411,
#  'Command': 412,
#  'Microcosmos': 413,
#  'Daytrippers,': 414,
#  'Amazing': 415,
#  'bolle': 416,
#  'Ugly,': 417,
#  'Leather': 418,
#  'Aardman': 419,
#  'Scrooged': 420,
#  'Hillbillys': 421,
#  'Antonin': 422,
#  'Bewegte': 423,
#  'Female': 424,
#  'Must': 425,
#  'Violenza': 426,
#  'Newmar': 427,
#  'Line': 428,
#  'Sleepwalkers': 429,
#  '(Sibak)': 430,
#  'Babe': 431,
#  'Sid': 432,
#  'Dreaming': 433,
#  'Fire,': 434,
#  'angefangen)': 435,
#  'Supper,': 436,
#  'Lambs,': 437,
#  'London,': 438,
#  "Pharaoh's": 439,
#  'Mickey': 440,
#  'Del': 441,
#  'Abominable': 442,
#  'Vu': 443,
#  'Savage': 444,
#  'Bandit': 445,
#  'Separation,': 446,
#  'Innocent': 447,
#  'Bewitched,': 448,
#  'Professore!': 449,
#  'Sundance': 450,
#  "Charm's": 451,
#  'Horse': 452,
#  'Penny': 453,
#  'Navarone,': 454,
#  'Amityville:': 455,
#  'Trek': 456,
#  'Letter': 457,
#  'Engel)': 458,
#  'Crossing': 459,
#  'ge': 460,
#  'Irene': 461,
#  'Loved': 462,
#  'Knot': 463,
#  'Hate,': 464,
#  'Inspector': 465,
#  'End': 466,
#  'Velvet': 467,
#  'NIMH,': 468,
#  'Fear:': 469,
#  'Half': 470,
#  'Mulholland': 471,
#  'Love,': 472,
#  'Vie)': 473,
#  'Little': 474,
#  'Voices,': 475,
#  'vida': 476,
#  'Sorcerer': 477,
#  'Quest': 478,
#  'Professional)': 479,
#  'Freedom': 480,
#  'Entertaining': 481,
#  'Cigarettes': 482,
#  'Lamerica': 483,
#  'Gilda': 484,
#  'Smell': 485,
#  'Degrees': 486,
#  'Shine': 487,
#  'Web': 488,
#  'Crisis': 489,
#  'T-Men': 490,
#  'Cold,': 491,
#  'Heathers': 492,
#  'Senior': 493,
#  'Foo,': 494,
#  'Wedding': 495,
#  'Dracula': 496,
#  'Designated': 497,
#  'Liaison': 498,
#  'Badlands': 499,
#  'Stone': 500,
#  'B.': 501,
#  'dou': 502,
#  'Room': 503,
#  'Sunrise': 504,
#  'Asfour': 505,
#  'Meet': 506,
#  "Mat'": 507,
#  'Costa': 508,
#  'Zhivago': 509,
#  'Earthbound': 510,
#  'quan)': 511,
#  'Effect,': 512,
#  'In': 513,
#  'Lesson,': 514,
#  'Topsy-Turvy': 515,
#  'Sorority': 516,
#  'Sefid': 517,
#  'Spanking': 518,
#  'Source,': 519,
#  'Armed': 520,
#  'Tigger': 521,
#  'Earp': 522,
#  'il': 523,
#  'Willow': 524,
#  'qui': 525,
#  '98': 526,
#  'Follia)': 527,
#  'Much,': 528,
#  'Run': 529,
#  'Raven,': 530,
#  'Patient,': 531,
#  'Passage': 532,
#  'Hollywood': 533,
#  'Odyssey': 534,
#  'Kagemusha': 535,
#  'Bram': 536,
#  'Paura,': 537,
#  'Paycock': 538,
#  'Fishes': 539,
#  'Marked': 540,
#  '(Jing': 541,
#  'Gone': 542,
#  'Hype,': 543,
#  'Joan': 544,
#  'Breathing': 545,
#  'Carnale)': 546,
#  'Zoe': 547,
#  'klaka)': 548,
#  'Virgin': 549,
#  'Calls': 550,
#  'Captives': 551,
#  '(Travolti': 552,
#  'Navarone': 553,
#  'Spirits': 554,
#  'Wanna': 555,
#  'Got': 556,
#  '39': 557,
#  'Human,': 558,
#  'Valentino': 559,
#  'que': 560,
#  'Runnings': 561,
#  'Shots': 562,
#  'Slumberland': 563,
#  'Face,': 564,
#  'Wonders': 565,
#  '(Mia': 566,
#  'U2:': 567,
#  'Crows': 568,
#  'Arrest': 569,
#  'dozhdot)': 570,
#  'Barb': 571,
#  'hui)': 572,
#  'Lead': 573,
#  'Circle,': 574,
#  'Guinevere': 575,
#  '7': 576,
#  "Marvin's": 577,
#  'About': 578,
#  'Jaguar': 579,
#  'ojos)': 580,
#  'Crow:': 581,
#  'Palace,': 582,
#  'Waterworld': 583,
#  'Slaves': 584,
#  'Grace': 585,
#  'Tramp': 586,
#  'Might': 587,
#  '(K�disbellan': 588,
#  'League': 589,
#  'Died': 590,
#  '20th': 591,
#  'Knights,': 592,
#  'as': 593,
#  'Retrouv�)': 594,
#  'Paulie': 595,
#  'Guys': 596,
#  'Saphead,': 597,
#  'Beginning': 598,
#  'Bowles': 599,
#  'para': 600,
#  'Theory': 601,
#  'Thoughts': 602,
#  'Wine': 603,
#  'Benjamenta,': 604,
#  'Ladyhawke': 605,
#  'Heart': 606,
#  'Goodnight,': 607,
#  'X-Files:': 608,
#  '(Feiying': 609,
#  'Jonah': 610,
#  'Week': 611,
#  'Sum': 612,
#  'Dellamore)': 613,
#  'La)': 614,
#  'Loaded': 615,
#  'Grit': 616,
#  'Very': 617,
#  'Police': 618,
#  '(Dead': 619,
#  'Grapes': 620,
#  'Polar)': 621,
#  'Trial,': 622,
#  'Fancy': 623,
#  'Helena': 624,
#  'Go': 625,
#  'syn': 626,
#  'Cool': 627,
#  'Chasing': 628,
#  'coups)': 629,
#  'Pagemaster,': 630,
#  'Extra-Terrestrial': 631,
#  'Fruit': 632,
#  'Cheerleader': 633,
#  'Firm,': 634,
#  'Condition': 635,
#  'Character': 636,
#  '1st': 637,
#  'Madness': 638,
#  'Paper,': 639,
#  '(Abre': 640,
#  'Heads': 641,
#  "Heinlein's": 642,
#  'Catastrophes': 643,
#  'Remagen,': 644,
#  'Rush,': 645,
#  'Parker': 646,
#  'III,': 647,
#  'Endless': 648,
#  'Beautiful': 649,
#  'Is': 650,
#  'Pussycat!': 651,
#  'Incognito': 652,
#  'Waiting': 653,
#  'Juction': 654,
#  'Murder!': 655,
#  'Corrina,': 656,
#  'Bug,': 657,
#  'Shrews,': 658,
#  'Gate,': 659,
#  'Still,': 660,
#  'Wally': 661,
#  '(Zui': 662,
#  'Postino,': 663,
#  'William': 664,
#  'Bleeding': 665,
#  'Lisa': 666,
#  'Indochine': 667,
#  'peuple': 668,
#  'en': 669,
#  'Priest': 670,
#  'Dwarf,': 671,
#  'I.Q.': 672,
#  'Oz,': 673,
#  'Voyage': 674,
#  'Kentucky': 675,
#  'Rangoon': 676,
#  'Cujo': 677,
#  "Schindler's": 678,
#  'Room,': 679,
#  'Turning,': 680,
#  'Warrior)': 681,
#  'dao': 682,
#  'Frankie': 683,
#  'Show,': 684,
#  "Don't": 685,
#  'Cape': 686,
#  'Millionaire,': 687,
#  'Tess': 688,
#  'Kombat': 689,
#  'Evening': 690,
#  'Amants': 691,
#  'Rose': 692,
#  'Fled': 693,
#  'Titus': 694,
#  '(Yi': 695,
#  'Annihilation': 696,
#  'Dumber': 697,
#  'Tomb,': 698,
#  "Murphy's": 699,
#  'Dreamed': 700,
#  'Barcelona': 701,
#  'Jumanji': 702,
#  'Beloved': 703,
#  "Can't": 704,
#  'Solari)': 705,
#  'Hills': 706,
#  'Tainted': 707,
#  'Halloween': 708,
#  'Hat': 709,
#  'Tilt': 710,
#  'Bicycle': 711,
#  'Shadrach': 712,
#  'Carnosaur': 713,
#  'Jericho': 714,
#  '81': 715,
#  'After,': 716,
#  'Beach': 717,
#  'God': 718,
#  '(Zerkalo)': 719,
#  'Buffy': 720,
#  'Assignment,': 721,
#  'Skipped': 722,
#  'enfants': 723,
#  'Know': 724,
#  'Cat!': 725,
#  'Ghosts': 726,
#  'Chopping': 727,
#  'Little,': 728,
#  'Glenn': 729,
#  'Cupboard,': 730,
#  'Passi': 731,
#  'Welt)': 732,
#  'Beavis': 733,
#  'Quiet': 734,
#  'Future,': 735,
#  'Cleaning': 736,
#  'Unforgotten:': 737,
#  'Shooter,': 738,
#  'Cup,': 739,
#  '(Der': 740,
#  "Love's": 741,
#  'Risky': 742,
#  'Saves': 743,
#  'Tide': 744,
#  'Interiors': 745,
#  'Wore': 746,
#  'Bloodsport': 747,
#  '(Bacheha-Ye': 748,
#  'Nine': 749,
#  'Corruptor,': 750,
#  'There,': 751,
#  'Howling': 752,
#  'Autumn': 753,
#  'Wales,': 754,
#  'Tibet': 755,
#  '(Corpi': 756,
#  'Hellraiser': 757,
#  '8MM': 758,
#  'Nil': 759,
#  'Distress,': 760,
#  'Journals': 761,
#  'Waterboy,': 762,
#  'D.A.,': 763,
#  'destino': 764,
#  'Celtic': 765,
#  'Tracy': 766,
#  'X:': 767,
#  'Woke': 768,
#  'Bank': 769,
#  'Nightmares': 770,
#  'Journey': 771,
#  '(ID4)': 772,
#  'ce': 773,
#  'Road': 774,
#  'Clear': 775,
#  'Specialist,': 776,
#  'Gesture,': 777,
#  'Emerald': 778,
#  'Limbo': 779,
#  'Polish': 780,
#  'Mamma': 781,
#  '(E': 782,
#  'Memories': 783,
#  'Thumbelina': 784,
#  'Terrorist,': 785,
#  'Stir': 786,
#  'mich)': 787,
#  'Jungle': 788,
#  'Strangers': 789,
#  'Atlantic': 790,
#  'Ravenous': 791,
#  'Conqueror': 792,
#  'Beetlejuice': 793,
#  'Blazing': 794,
#  'Pop': 795,
#  'Day,': 796,
#  'Attraction': 797,
#  'Comes': 798,
#  "Wayne's": 799,
#  'Urban': 800,
#  'Empty': 801,
#  'Mulan': 802,
#  'Law,': 803,
#  '(Idioterne)': 804,
#  '(Longxiong': 805,
#  'Telling': 806,
#  'Hunted': 807,
#  'Rudy': 808,
#  'Coney': 809,
#  'Zulu': 810,
#  'Mediterraneo': 811,
#  'Passion': 812,
#  'Preferred...': 813,
#  'Excess': 814,
#  'Hoogste': 815,
#  'Bachelor,': 816,
#  'Time': 817,
#  'Annie': 818,
#  'Hornblower': 819,
#  'Speechless': 820,
#  'Armageddon': 821,
#  'Locomotive': 822,
#  'Arlington': 823,
#  'Tommy': 824,
#  'Kill': 825,
#  'Less': 826,
#  'Faces,': 827,
#  'Advocate,': 828,
#  'Doctor': 829,
#  'Christ,': 830,
#  'Smith': 831,
#  'Romper': 832,
#  'Question,': 833,
#  'Ever': 834,
#  'Sticky': 835,
#  '13': 836,
#  'Leopold': 837,
#  'Steamboat': 838,
#  'Santa': 839,
#  'gar�on': 840,
#  "Sullivan's": 841,
#  'Khoda)': 842,
#  'Barry': 843,
#  'Company': 844,
#  'Nadine': 845,
#  'Powers:': 846,
#  'Baton': 847,
#  'Sugarland': 848,
#  'Damsel': 849,
#  'Wisdom': 850,
#  'Closer': 851,
#  'Desire': 852,
#  'Fair': 853,
#  '(Io': 854,
#  '(En': 855,
#  'He': 856,
#  'Head': 857,
#  'Critical': 858,
#  'Would': 859,
#  'Roxbury,': 860,
#  'Johnny': 861,
#  'Tora!': 862,
#  'Solas': 863,
#  'Monument': 864,
#  'Hyena)': 865,
#  'Clouds,': 866,
#  'Home:': 867,
#  'Jefferson': 868,
#  '54': 869,
#  'Habit': 870,
#  'Far': 871,
#  'Bag': 872,
#  'shuang': 873,
#  'Miami': 874,
#  'Morant': 875,
#  'Rosewood': 876,
#  'Pitch': 877,
#  'Of': 878,
#  'Noon': 879,
#  'Federal': 880,
#  'L.A.': 881,
#  'A.': 882,
#  'Strong': 883,
#  'Dollars,': 884,
#  'Brava': 885,
#  'Coast,': 886,
#  'Retro': 887,
#  'Superweib,': 888,
#  'Rosencrantz': 889,
#  'Chuck': 890,
#  'Sin': 891,
#  "d'Agosto)": 892,
#  '(Bian': 893,
#  'Clan': 894,
#  'Lin:': 895,
#  'Chinois': 896,
#  '(Mitt': 897,
#  'Common': 898,
#  'Left': 899,
#  'Auntie': 900,
#  'cousin!': 901,
#  'Return': 902,
#  'Bodeos)': 903,
#  'Apes': 904,
#  'Modern': 905,
#  'Cherbourg,': 906,
#  'Gillian': 907,
#  'Christmas': 908,
#  'Perversions': 909,
#  'Prince': 910,
#  'Desperate': 911,
#  'Broadcast': 912,
#  'Mifune': 913,
#  'Coyote': 914,
#  'Pet': 915,
#  'Panther,': 916,
#  'Pointe': 917,
#  'Creatures': 918,
#  'Rapture,': 919,
#  'Affair': 920,
#  'Men,': 921,
#  'King,': 922,
#  'stelle,': 923,
#  'Alabama': 924,
#  'G.I.': 925,
#  'Sons': 926,
#  'Combo,': 927,
#  'Rabbit?': 928,
#  'Naturally': 929,
#  'Sting,': 930,
#  'Jewel': 931,
#  '(Rekopis': 932,
#  'Honor': 933,
#  'Ligeia,': 934,
#  'I': 935,
#  'Reunion': 936,
#  'Plan�te': 937,
#  'Ladder': 938,
#  'Brain': 939,
#  'On': 940,
#  'Dugan': 941,
#  'Ayn': 942,
#  'Do-Right': 943,
#  'Ocean,': 944,
#  'Terms': 945,
#  'Beauties': 946,
#  'Oficial)': 947,
#  'Dawn)': 948,
#  'Tail:': 949,
#  '(Haine,': 950,
#  'Criminals': 951,
#  'Die,': 952,
#  'Lawn': 953,
#  'Dragons': 954,
#  'Martin)': 955,
#  'Halfmoon': 956,
#  'rennt)': 957,
#  'Seeking': 958,
#  'Deadtime': 959,
#  'Dolores': 960,
#  '(Chao': 961,
#  'Jesse': 962,
#  'To': 963,
#  'VII:': 964,
#  "'77": 965,
#  'Misery': 966,
#  'arriv�': 967,
#  'Railroad': 968,
#  'Daughter': 969,
#  'Stein)': 970,
#  'Rent-a-Kid': 971,
#  'Paralyzing': 972,
#  'Tequila': 973,
#  'Convent,': 974,
#  'Guts,': 975,
#  'West': 976,
#  'Dying': 977,
#  'Det)': 978,
#  'Sgt.': 979,
#  'Hillbillies,': 980,
#  'Swept': 981,
#  'D�ner': 982,
#  'Hurricane,': 983,
#  'Clause,': 984,
#  'Eighty-Four': 985,
#  'Alarmist,': 986,
#  'Roy': 987,
#  'Everything': 988,
#  'Ruth': 989,
#  'Snake': 990,
#  '(Retour': 991,
#  'Shrew,': 992,
#  'Henge)': 993,
#  'Flier': 994,
#  'Lured': 995,
#  'Sierra': 996,
#  'Maltese': 997,
#  'Story': 998,
#  'True': 999,
#  ...}

# %%
#将电影Title转成等长数字列表，长度是15
title_count = 15
title_map = {val:[title2int[row] for row in val.split()] for ii,val in enumerate(set(movies['Title']))}

for key in title_map:
    for cnt in range(title_count - len(title_map[key])):
        title_map[key].insert(len(title_map[key]) + cnt,title2int['<PAD>'])

movies['Title'] = movies['Title'].map(title_map)

# %%
movies['Title'][100]
# Out:
# [4115,
#  4975,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982,
#  4982]

# %%
movies_orig[100]
# Out:
# array([102, 'Mr. Wrong (1996)', 'Comedy'], dtype=object)

# %%
list(title2int.keys())[list(title2int.values()).index(2870)]
# Out:
# 'Mission'

# %%
list(title2int.keys())[list(title2int.values()).index(3789)]
# Out:
# 'Arizona'

# %%
list(title2int.keys())[list(title2int.values()).index(3476)]
# Out:
# 'Chips'

# %%
def load_data():
    """
    Load Dataset from File
    """
    # 读取User数据
    users_title = ['UserID', 'Gender', 'Age', 'JobID', 'Zip-code']
    users = pd.read_table('./ml-1m/users.dat', sep='::', header=None, names=users_title, engine = 'python')
    users = users.filter(regex='UserID|Gender|Age|JobID')
    users_orig = users.values
    # 改变User数据中性别和年龄
    gender_map = {'F':0, 'M':1}
    users['Gender'] = users['Gender'].map(gender_map)

    age_map = {item:index for index,item in enumerate([1,18,25,35,45,50,56])}
    users['Age'] = users['Age'].map(age_map)

    # 读取Movie数据集
    movies_title = ['MovieID', 'Title', 'Genres']
    movies = pd.read_table('./ml-1m/movies.dat', sep='::', header=None, names=movies_title, engine = 'python')
    movies_orig = movies.values
    # 将Title中的年份去掉
    pattern = re.compile(r'^(.*)\((\d+)\)$')

    title_map = {item:pattern.match(item).group(1) for index,item in enumerate(set(movies['Title']))}
    movies['Title'] = movies['Title'].map(title_map)

    # 电影类型转数字字典
    genres_set = set()
    for item in movies['Genres'].str.split('|'):
        genres_set.update(item)

    genres_set.add('<PAD>')
    genres2int = {item:index for index,item in enumerate(genres_set)}

    # 将电影类型转成等长数字列表，长度是18
    genres_map = {item:[genres2int[row] for row in item.split('|')] for index,item in enumerate(set(movies['Genres']))}

    for key in genres_map:
        for cnt in range(max(genres2int.values()) - len(genres_map[key])):
            genres_map[key].insert(len(genres_map[key]) + cnt,genres2int['<PAD>'])
    
    movies['Genres'] = movies['Genres'].map(genres_map)

    # 电影Title转数字字典
    title_set = set()
    for val in movies['Title'].str.split():
        title_set.update(val)
    
    title_set.add('<PAD>')
    title2int = {val:ii for ii, val in enumerate(title_set)}

    # 将电影Title转成等长数字列表，长度是15
    title_count = 15
    title_map = {item:[title2int[row] for row in item.split()] for index,item in enumerate(set(movies['Title']))}
    
    for key in title_map:
        for cnt in range(title_count - len(title_map[key])):
            title_map[key].insert(len(title_map[key]) + cnt,title2int['<PAD>'])
    
    movies['Title'] = movies['Title'].map(title_map)

    # 读取评分数据集
    ratings_title = ['UserID','MovieID', 'ratings', 'timestamps']
    ratings = pd.read_table('./ml-1m/ratings.dat', sep='::', header=None, names=ratings_title, engine = 'python')
    ratings = ratings.filter(regex='UserID|MovieID|ratings')

    # 合并三个表
    data = pd.merge(pd.merge(ratings, users), movies)
    
    # 将数据分成X和y两张表
    target_fields = ['ratings']
    features_pd, targets_pd = data.drop(target_fields, axis=1), data[target_fields]
    
    features = features_pd.values
    targets_values = targets_pd.values
    
    return title_count, title_set, genres2int, features, targets_values, ratings, users, movies, data, movies_orig, users_orig

# %%
title_count, title_set, genres2int, features, targets_values, ratings, users, movies, data, movies_orig, users_orig = load_data()

# %%
data.head()
# Out:
#    UserID  MovieID  ratings  Gender  Age  JobID  \
# 0       1     1193        5       0    0     10
# 1       2     1193        5       1    6     16
# 2      12     1193        4       1    2     12
# 3      15     1193        4       1    2      7
# 4      17     1193        5       1    5      1
#
#                                                Title  \
# 0  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
# 1  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
# 2  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
# 3  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
# 4  [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982...
#
#                                               Genres
# 0  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 1  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 2  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 3  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 4  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...

# %%
features
# Out:
# array([[1, 1193, 0, ..., 10,
#         [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        [2, 1193, 1, ..., 16,
#         [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        [12, 1193, 1, ..., 12,
#         [2077, 3571, 3400, 1316, 379, 3314, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        ...,
#        [5780, 2845, 1, ..., 17,
#         [4419, 2803, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        [5851, 3607, 0, ..., 20,
#         [2077, 474, 2453, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [6, 9, 13, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]],
#        [5938, 2909, 1, ..., 1,
#         [1269, 2979, 3369, 2510, 2628, 1013, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982, 4982],
#         [10, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]]], dtype=object)

# %%
features.take(0,1)
# Out:
# array([1, 2, 12, ..., 5780, 5851, 5938], dtype=object)
